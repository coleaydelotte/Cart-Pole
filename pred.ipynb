# %%
import pandas as pd

# %%
data = pd.read_csv('pred.csv')
data
# Out:
#                            TEAM  SUPER BOWL  CONFERENCE        DIVISION  \
# Buffalo Bills            "+550"      "+275"      "-700"   "12.5 (-120 O
# Baltimore Ravens         "+650"      "+325"      "-140"   "11.5 (+110 O
# Philadelphia Eagles      "+700"      "+325"      "-160"   "11.5 (+100 O
# Green Bay Packers        "+800"      "+360"      "-125"   "11.5 (+105 O
# Kansas City Chiefs       "10-1"      "+450"      "+160"   "10.5 (-105 O
# Detroit Lions            "14-1"      "+900"      "+375"    "9.5 (+115 O
# San Francisco 49ers      "16-1"      "+900"      "+145"   "10.5 (-120 O
# Los Angeles Chargers     "18-1"      "+900"      "+200"    "9.5 (-145 O
# Washington Commanders    "18-1"      "10-1"      "+200"    "9.5 (-110 O
# Los Angeles Rams         "20-1"      "+900"      "+175"   "10.5 (+110 O
# Cincinnati Bengals       "20-1"      "10-1"      "+225"    "9.5 (-130 O
# Tampa Bay Buccaneers     "25-1"      "12-1"      "-200"    "9.5 (-135 O
# ...

# %%
data.info()
